# %% [markdown]
# ### Distribution map of COVID-19 cases in Ceará
#
# The final map is intended to be submitted to wikidata item [Q90267612](https://www.wikidata.org/wiki/Q90267612).
#
# The [original notebook](https://github.com/lubianat/covid_19_sandbox/blob/master/sao_paulo_covid/Map%20of%20Covid-19%20Cases%20in%20S%C3%A3o%20Paulo.ipynb) was made by Tiago Lubiana for São Paulo state, this is merely an adaption, so thank him!

# %%
import pandas as pd
from datetime import date,datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import requests

# %% [markdown]
# Thanks a lot to [André Campos](https://github.com/andreloc) for his workshop in Open Data Day - Fortaleza teaching how to use the Integrasus API, which I attended. The following code snippet is his creation.

# %%
def get_dataframe(api_url, id_municipio=''):    
    api_url = api_url + '?'
    if(id_municipio != ''): 
        api_url = '{}idMunicipio={}&'.format(api_url, id_municipio)
    
    result = requests.get(api_url)
    result = result.json()    
    result = pd.DataFrame.from_dict(result)
    
    if(id_municipio != ''): 
        result.insert(0, 'idMunicipio', id_municipio)
        
    return result

# %%
api_endpoint = "https://indicadores.integrasus.saude.ce.gov.br/api/coronavirus/qtd-por-dia-tipo"
qtd_por_municipios  = get_dataframe('https://indicadores.integrasus.saude.ce.gov.br/api/coronavirus/qtd-por-municipio')

# %%
qtd_por_municipios = qtd_por_municipios.query("tipo == 'Confirmado'")
qtd_por_municipios
# Out:
#            tipo  idMunicipio  qtdSuspeito             municipio  qtdObito  \
# 191  Confirmado     230030.0          NaN              ACOPIARA       NaN
# 192  Confirmado     230075.0          NaN              AMONTADA       NaN
# 193  Confirmado     230100.0          NaN               AQUIRAZ       NaN
# 194  Confirmado     230110.0          NaN               ARACATI       NaN
# 195  Confirmado     230205.0          NaN           BARROQUINHA       NaN
# 196  Confirmado     230220.0          NaN              BEBERIBE       NaN
# 197  Confirmado     230280.0          NaN               CANINDE       NaN
# 198  Confirmado     230330.0          NaN                CARIUS       NaN
# 199  Confirmado     230350.0          NaN              CASCAVEL       NaN
# 200  Confirmado     230360.0          NaN              CATARINA       NaN
# 201  Confirmado     230370.0          NaN               CAUCAIA       NaN
# 202  Confirmado     230410.0          NaN               CRATEUS       NaN
# 203  Confirmado     230420.0          NaN                 CRATO       NaN
# 204  Confirmado     230423.0          NaN                CROATA       NaN
# 205  Confirmado     230428.0          NaN               EUSEBIO       NaN
# 206  Confirmado     230430.0          NaN          FARIAS BRITO       NaN
# 207  Confirmado     230440.0          NaN             FORTALEZA       NaN
# 208  Confirmado     230445.0          NaN                FORTIM       NaN
# 209  Confirmado     230465.0          NaN                 GRACA       NaN
# 210  Confirmado     230500.0          NaN   GUARACIABA DO NORTE       NaN
# 211  Confirmado     230523.0          NaN             HORIZONTE       NaN
# 212  Confirmado     230535.0          NaN                ICAPUI       NaN
# 213  Confirmado     230540.0          NaN                   ICO       NaN
# 214  Confirmado     230550.0          NaN                IGUATU       NaN
# 215  Confirmado     230560.0          NaN         INDEPENDENCIA       NaN
# 216  Confirmado     230565.0          NaN            IPAPORANGA       NaN
# 217  Confirmado     230590.0          NaN              IPUEIRAS       NaN
# 218  Confirmado     230620.0          NaN              ITAICABA       NaN
# 219  Confirmado     230625.0          NaN             ITAITINGA       NaN
# 220  Confirmado     230630.0          NaN               ITAPAJE       NaN
# 221  Confirmado     230640.0          NaN             ITAPIPOCA       NaN
# 222  Confirmado     230655.0          NaN               ITAREMA       NaN
# 223  Confirmado     230690.0          NaN             JAGUARIBE       NaN
# 224  Confirmado     230730.0          NaN     JUAZEIRO DO NORTE       NaN
# 225  Confirmado     230750.0          NaN  LAVRAS DA MANGABEIRA       NaN
# 226  Confirmado     230760.0          NaN     LIMOEIRO DO NORTE       NaN
# 227  Confirmado     230765.0          NaN             MARACANAU       NaN
# 228  Confirmado     230770.0          NaN            MARANGUAPE       NaN
# 229  Confirmado     230810.0          NaN               MAURITI       NaN
# 230  Confirmado     230850.0          NaN               MOMBACA       NaN
# 231  Confirmado     230940.0          NaN          NOVO ORIENTE       NaN
# 232  Confirmado     230960.0          NaN               PACAJUS       NaN
# 233  Confirmado     230970.0          NaN              PACATUBA       NaN
# 234  Confirmado     231020.0          NaN              PARACURU       NaN
# 235  Confirmado     231085.0          NaN           PINDORETAMA       NaN
# 236  Confirmado     231130.0          NaN               QUIXADA       NaN
# 237  Confirmado     231140.0          NaN          QUIXERAMOBIM       NaN
# 238  Confirmado     231150.0          NaN               QUIXERE       NaN
# 239  Confirmado     231180.0          NaN                RUSSAS       NaN
# 240  Confirmado     231200.0          NaN     SANTANA DO ACARAU       NaN
# 241  Confirmado     231220.0          NaN        SANTA QUITERIA       NaN
# 242  Confirmado     231260.0          NaN      SAO LUÍS DO CURU       NaN
# 243  Confirmado     231270.0          NaN        SENADOR POMPEU       NaN
# 244  Confirmado     231280.0          NaN            SENADOR SA       NaN
# 245  Confirmado     231290.0          NaN                SOBRAL       NaN
# 246  Confirmado     231310.0          NaN    TABULEIRO DO NORTE       NaN
# 247  Confirmado     231340.0          NaN               TIANGUA       NaN
# 248  Confirmado     231350.0          NaN                TRAIRI       NaN
# 249  Confirmado     231400.0          NaN         VARZEA ALEGRE       NaN
# 250  Confirmado          NaN          NaN        Sem informação       NaN
#
#      qtdConfirmado
# 191            1.0
# 192            1.0
# 193           30.0
# 194            3.0
# 195            1.0
# 196            2.0
# 197            1.0
# 198            2.0
# 199            1.0
# 200            1.0
# 201           38.0
# 202            1.0
# 203            2.0
# 204            1.0
# 205            7.0
# 206            1.0
# 207         1714.0
# 208            1.0
# 209            1.0
# 210            1.0
# 211            7.0
# 212            2.0
# 213            3.0
# 214            7.0
# 215            2.0
# 216            1.0
# 217            2.0
# 218            1.0
# 219            5.0
# 220            1.0
# 221            2.0
# 222            1.0
# 223            5.0
# 224            3.0
# 225            1.0
# 226            4.0
# 227           28.0
# 228            4.0
# 229            1.0
# 230            3.0
# 231            2.0
# 232            1.0
# 233            3.0
# 234            1.0
# 235            1.0
# 236            9.0
# 237            3.0
# 238            2.0
# 239            3.0
# 240            1.0
# 241            1.0
# 242            1.0
# 243            2.0
# 244            1.0
# 245           17.0
# 246            1.0
# 247            3.0
# 248            1.0
# 249            1.0
# 250           29.0

# %%
np.sum(qtd_por_municipios['qtdConfirmado'])
# Out:
# 1976.0

# %%
mapa_dos_municipios = gpd.read_file("../../estados_shapes/unzipped/23MUE250GC_SIR.shp")

# %%
mapa_dos_municipios.columns = ['municipio', 'idMunicipio', 'geometry']
mapa_dos_municipios.head()
# Out:
#   municipio idMunicipio                                           geometry
# 0   ABAIARA     2300101  POLYGON ((-38.97030 -7.42638, -38.97030 -7.426...
# 1   ACARAPE     2300150  POLYGON ((-38.61977 -4.16438, -38.61985 -4.169...
# 2    ACARAÚ     2300200  POLYGON ((-39.94349 -2.86047, -39.94722 -2.870...
# 3  ACOPIARA     2300309  POLYGON ((-39.05229 -6.02587, -39.05247 -6.038...
# 4    AIUABA     2300408  POLYGON ((-40.08511 -6.36860, -40.08445 -6.370...

# %%
ce_conf = qtd_por_municipios.loc[:,['municipio', 'qtdConfirmado']]

# %%
mapa_dos_municipios['municipio'] = mapa_dos_municipios['municipio']
map_conf = pd.merge(mapa_dos_municipios, ce_conf, on='municipio', how='left')
map_conf
# Out:
#            municipio idMunicipio  \
# 0            ABAIARA     2300101
# 1            ACARAPE     2300150
# 2             ACARAÚ     2300200
# 3           ACOPIARA     2300309
# 4             AIUABA     2300408
# ..               ...         ...
# 179      URUBURETAMA     2313807
# 180           URUOCA     2313906
# 181          VARJOTA     2313955
# 182    VÁRZEA ALEGRE     2314003
# 183  VIÇOSA DO CEARÁ     2314102
#
#                                               geometry  qtdConfirmado
# 0    POLYGON ((-38.97030 -7.42638, -38.97030 -7.426...            NaN
# 1    POLYGON ((-38.61977 -4.16438, -38.61985 -4.169...            NaN
# 2    POLYGON ((-39.94349 -2.86047, -39.94722 -2.870...            NaN
# 3    POLYGON ((-39.05229 -6.02587, -39.05247 -6.038...            1.0
# 4    POLYGON ((-40.08511 -6.36860, -40.08445 -6.370...            NaN
# ..                                                 ...            ...
# 179  POLYGON ((-39.45588 -3.64239, -39.45588 -3.642...            NaN
# 180  POLYGON ((-40.69245 -3.24248, -40.66954 -3.247...            NaN
# 181  POLYGON ((-40.43172 -4.09169, -40.43229 -4.093...            NaN
# 182  POLYGON ((-39.10939 -6.71454, -39.10954 -6.715...            NaN
# 183  POLYGON ((-40.88885 -3.52244, -40.87687 -3.532...            NaN
#
# [184 rows x 4 columns]

# %%
map_conf["qtdConfirmado"] = map_conf["qtdConfirmado"].fillna(0)

map_conf["casos_categorizados"] = pd.cut(map_conf["qtdConfirmado"],
                                                    bins = [-1,1, 10,50,500,1000, 100000000],
                                                   labels = ["0", "1-10", "11-50", "51-500","501-1000", ">1000"])

# %%
fig, ax = plt.subplots()
ax = map_conf.plot(column='casos_categorizados',
                         categorical=True, 
                         legend=True, 
                         figsize=(100,6),
                         markersize=46,
                         cmap = "Reds",
                         edgecolor='k',
                         linewidth=0.1,
                         ax=ax);
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
leg = ax.get_legend()
leg.set_bbox_to_anchor((0., 0., 0.2, 0.2))
plt.savefig("figs/casos_ce_" + "13_april" + ".png", dpi = 300)
